# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# Our team was asked to analyze statewide participation and recommends where money is best spent to improve SAT participation rates.
# In our study we analyzed 2017 and 2018, SAT and ACT exam participation rates and scores. Our aim is to show the College Board which states prefer which exam.
#
# ## Problem Statement
#
# The College Board develops and administers  the SAT test. Board executive directors do not know if the SAT exam is preferred over the ACT exam.

# %% [markdown]
# ## Executive Summary
#
# The analysis relies on 4 datasets about 2017 and 2018 SAT and ACT exam scores and participation. The datasets are taken from related resources. Our team researched the general participation rates in each state, and sought for possible correlations between components of the each exam.
# General attendance in the SAT exam is low in comparison with the ACT exam and similar university entrance exams in other countries. In 2017, the SAT exam average participation rate was 39% in the Unites States.
# While there is only 1 state has lower than 15% average participation rate ACT exams, there are 18 states with lower than 15% average participation rate in the SAT exam.
# Seventeen states have 100% average participation in the ACT exam, while 5 states have 100% average participation in the SAT exam.
#
# Total score range is between 400 and 1600 the SAT exam and 1 and 36 for the ACT exam.
# The correlation between the SAT and the ACT exam total/composite scores is weak. Similarly, the correlation rates between average math and reading scores are weak also. In our study, we found out that generally, states with higher participation in the ACT exam, tend to have lower participation in the SAT exam.
#
# Our team suggests the College Board to to develop strategies for increasing participation in Florida, Ohio and Wisconsin. As described in detail in the report, those states have lower participation rates and higher scores and/or population.
#
# If you want to, it's great to use relative links to direct your audience to various sections of a notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)<a id="Data-Import-and-Cleaning">
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)<a id="2018-Data-Import-and-Cleaning">
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)<a id="Exploratory-Data-Analysis">
# - [Data Visualization](#Visualize-the-data)<a id="Visualize-the-data">
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)<a id="Descriptive-and-Inferential-Statistics">
# - [Outside Research](#Outside-Research)<a id="Outside-Research">
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)<a id="Conclusions-and-Recommendations">

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.** Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
#Imports:
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data
#
# Read in the `sat_2017.csv` and `act_2017.csv` files and assign them to appropriately named pandas dataframes.

# %%
#Reading the files:

sat_17 = pd.read_csv("sat_2017.csv")
act_17 = pd.read_csv("act_2017.csv")

# %% [markdown]
# #### 2. Display Data
#
# Print the first 10 rows of each dataframe to your jupyter notebook

# %%
# head() function to display first 10 rows
sat_17.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# head() function to display first 10 rows

act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %% [markdown]
# #### 3. Verbally Describe Data
#
# Take your time looking through the data and thoroughly describe the data in the markdown cell below.

# %% [markdown]
# Answer: 2017 SAT scores table shows each state's SAT participation rates, evidence-based reading writing , math score and total average scores. The states are sorted alphabetically.
# 2017 ACT scores table contains each state's ACT participation rates, the average scores in all of the subjects which are English, Math, Reading, Science and Composite. The dataset is sorted by states in alphabetical order, with one exception. In the first line, we see the national participartion rate and average scores.

# %% [markdown]
# #### 4a. Does the data look complete?

# %% [markdown]
# Answer: Sat 2017 score dataset covers all the states' scores, but national average. It is either missing or intentionally excluded. So, it does not look complete; but, we can calculate and add it.
# In both datasets there is nothing structurally missing.
# In the below codes we see that entry numbers and "Non-Null Count" numbers match for each column in both tables. That means there is not null entry.

# %%
# Using info() method to see Dtype and size of the DataFrame.
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Using info() method to see Dtype and size of the DataFrame.
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
sat_17["State"].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
act_17["State"].unique()
# Out:
# array(['National', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# Checking the descriptive statistics 
act_17.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# Note: Above table is not showing Composite. It's supposed to show it.
# There must be an error preventing it.

# %%
# Since we know there is a problem in the Composite column, we want to see what it is.
# We are showing the unique values in that column.
act_17["Composite"].unique()
# Out:
# array(['21.0', '19.2', '19.8', '19.7', '19.4', '22.8', '20.8', '25.2',
#        '24.1', '24.2', '21.4', '19.0', '22.3', '22.6', '21.9', '21.7',
#        '20.0', '19.5', '24.3', '23.6', '25.4', '21.5', '18.6', '20.4',
#        '20.3', '17.8', '25.5', '23.9', '19.1', '22.0', '21.8', '23.7',
#        '24.0', '18.7', '20.7', '23.8', '20.5', '20.2x'], dtype=object)

# %% [markdown]
# We see that the last value is not float.

# %%
# Checking the descriptive statistics 
sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# #### 4b. Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# Answer: For ACT test, score range is between 1 and 36 for each sction. A student can get maximum 36, while minimum 1 in ACT test.
# For SAT test, each section (Evidence-Based Reading & Writing, and Math) is scored between 200 - 800. In total (excluding the optional essay) a student can get maximum 400, while minimum 1600 in SAT test.

# %% [markdown]
# #### 4c. Fix any errors you identified
#
# **The data is available** so there's no need to guess or calculate anything. If you didn't find any errors, continue to the next step.

# %%
# We found out that some entries are incoreect in Maryland IN act_17.
# We are correcting them in below codes.

act_17[act_17["State"]=="Maryland"]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2      2.3      23.6

# %%
# Assigned the accurate value
act_17.loc[21,"Science"]=23.2

# %%
# confirming
act_17[act_17["State"]=="Maryland"]
# Out:
#        State Participation  English  Math  Reading  Science Composite
# 21  Maryland           28%     23.3  23.1     24.2     23.2      23.6

# %%
# We found out that some entries are incoreect in Maryland in SAT_17.
# We are correcting them in below codes.

sat_17[sat_17["State"]=="Maryland"]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536    52   1060

# %%
# Assigned the accurate value
sat_17.loc[20,"Math"]=524

# %%
#Confirming
sat_17[sat_17["State"]=="Maryland"]
# Out:
#        State Participation  Evidence-Based Reading and Writing  Math  Total
# 20  Maryland           69%                                 536   524   1060

# %%
# Few lines up, we caught an error in Composite columns. It was showing 20.2x
# In the below code, we are finding its exact location.

act_17[act_17["Composite"]=="20.2x"]
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6     20.2x

# %%
#We found out that the error is on 51st row, and "Composite" column.
# We double checked with the other resources. It's supposed to be 20.2.

# We are changing it.
act_17.loc[51,"Composite"]=20.2

act_17.tail(1) #It's corrected.
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 51  Wyoming          100%     19.4  19.8     20.8     20.6      20.2

# %% [markdown]
# #### 5. What are your data types?
# Display the data types of each feature.

# %%
#Checking the datatypes

print("=== sat_17 Dataframe ==") #sat 2017 exam
print(sat_17.dtypes)             #sat 2017 exam data type 
print("\n")                      # space
print("=== act_17 Dataframe ==") #sat 2018 exam 
act_17.dtypes                      #sat 2018 exam data type
# Out:
# === sat_17 Dataframe ==
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object
#
#
# === act_17 Dataframe ==
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %% [markdown]
# What did you learn?
# - Do any of them seem odd?
# - Which ones are not as they should be?

# %% [markdown]
# Answer:
# In act_17 table, Composite is object; but it should be float.
# Also, in both tables Participation columns should be float.

# %% [markdown]
# #### 6. Fix Incorrect Data Types
# Based on what you discovered above, use appropriate methods to re-type incorrectly typed data.
# - Define a function that will allow you to convert participation rates to an appropriate numeric type. Use `map` or `apply` to change these columns in each dataframe.

# %%
# Creating convert_to_float function to convert any column's integer datatype to float datatype.
def convert_to_float(x):
    return float(x.strip('%'))/100

# %%
# Applying it to act_17 Participation column.

act_17["Participation"] = act_17["Participation"].apply(convert_to_float)

# %%
# checking it to see if it worked.
act_17[["Participation"]].head()
# Out:
#    Participation
# 0           0.60
# 1           1.00
# 2           0.65
# 3           0.62
# 4           1.00

# %%
# Confirming with dtypes method.
act_17.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
# Applying the same function to sat_17 Participation column.

sat_17["Participation"] = sat_17["Participation"].apply(convert_to_float)

# %%
# checking it to see if it worked. 
sat_17[["Participation"]].head()
# Out:
#    Participation
# 0           0.05
# 1           0.38
# 2           0.30
# 3           0.03
# 4           0.53

# %%
# Confirming with dtypes method.

sat_17.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# - Fix any individual values preventing other columns from being the appropriate type.

# %% [markdown]
# Anser: There was a mistake in Composite column and Wyoming row in act_17 DataFrame. I corrected it in question 4c.

# %% [markdown]
# - Finish your data modifications by making sure the columns are now typed appropriately.

# %%
# Correcting Composite column in act_17 since there is no typo anymore. (
# We corrected the typo in question 4c.)

act_17[["Composite"]] = act_17[["Composite"]].astype("float")

# %% [markdown]
# - Display the data types again to confirm they are correct.

# %%
#Displaying datatypes for both DataFrames

print("=== sat_17 Dataframe ==")
print(sat_17.dtypes)
print("\n")
print("=== act_17 Dataframe ==")
act_17.dtypes
# Out:
# === sat_17 Dataframe ==
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object
#
#
# === act_17 Dataframe ==
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# #### 7. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference the SAT columns and the ACT columns. Your solution should map all column names being changed at once (no repeated singular name-changes). **We will be combining these data with some of the data from 2018, and so you should name columns in an appropriate way**.
#
# **Guidelines**:
# - Column names should be all lowercase (you will thank yourself when you start pushing data to SQL later in the course)
# - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`.
# - Column names should be unique and informative (the only feature that we actually share between dataframes is the state).

# %%
#Using rename function to change column names.
act_17.rename(columns={"State":"state", 
                       "Participation":"act_17_participation",
                       "English":"act_17_english", 
                       "Math": "act_17_math",
                       "Reading":"act_17_reading",
                       "Science" : "act_17_science",
                       "Composite" : "act_17_composite"
                      }, inplace=True)

# %%
# Checking it
act_17.head()
# Out:
#       state  act_17_participation  act_17_english  act_17_math  \
# 0  National                  0.60            20.3         20.7
# 1   Alabama                  1.00            18.9         18.4
# 2    Alaska                  0.65            18.7         19.8
# 3   Arizona                  0.62            18.6         19.8
# 4  Arkansas                  1.00            18.9         19.0
#
#    act_17_reading  act_17_science  act_17_composite
# 0            21.4            21.0              21.0
# 1            19.7            19.4              19.2
# 2            20.4            19.9              19.8
# 3            20.1            19.8              19.7
# 4            19.7            19.5              19.4

# %%
#Using rename function to change column names.

sat_17.rename(columns={"State":"state", 
                       "Participation":"sat_17_participation",
                       "Evidence-Based Reading and Writing":"sat_17_evidence_based_reading_and_writing", 
                       "Math": "sat_17_math",
                       "Total":"sat_17_total",
                      }, inplace=True)

# %%
# Confirming if it worked
sat_17.head()
# Out:
#         state  sat_17_participation  \
# 0     Alabama                  0.05
# 1      Alaska                  0.38
# 2     Arizona                  0.30
# 3    Arkansas                  0.03
# 4  California                  0.53
#
#    sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total
# 0                                        593          572          1165
# 1                                        547          533          1080
# 2                                        563          553          1116
# 3                                        614          594          1208
# 4                                        531          524          1055

# %% [markdown]
# #### 8. Create a data dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |sat_17_state|object|sat_17|Each state names|
# |sat_17_participation|float|sat_17| High school graduates who took the SAT test during high school over the total number of high school graduates in 2017 by each state. |
# |sat_17_evidence_based_reading_and_writing|int|sat_17|Average evidence-based reading and writing score in the particular state in SAT exam in 2017.|
# |sat_17_math|int|sat_17|Average math score in the particular state in SAT exam in 2017.|
# |sat_17_total|int|sat_17|Average total score in the particular state in SAT exam in 2017.|
# |act_17_state|int|act_17|Each state names|
# |act_17_participation|float|act_17|High school graduates who took the ACT test during high school over the total number of high school graduates in 2017 by each state.|
# |act_17_english|float|act_17|Average English score in the particular state in ACT exam in 2017.|
# |act_17_reading|float|act_17|Average reading score in the particular state in ACT exam in 2017.|
# |act_17_math|float|act_17|Average math score in the particular state in ACT exam in 2017.|
# |act_17_science|float|act_17|Average science score in the particular state in ACT exam in 2017.|
# |act_17_composite|float|act_17|Average composite score in the particular state in ACT exam in 2017.|

# %% [markdown]
# #### 9. Drop unnecessary rows
#
# One of our dataframes contains an extra row. Identify and remove this from the dataframe.

# %%
"""When we run .head() functions for both DataFrames, 
we see that act_17 DataFrame has an extra row on index 0. It is showing "National" numbers.
We are dropping it with the below code."""

act_17.drop(axis="index",index=0, inplace=True)

# %%
# Confirming if it worked.
act_17.head()
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 1     Alabama                  1.00            18.9         18.4
# 2      Alaska                  0.65            18.7         19.8
# 3     Arizona                  0.62            18.6         19.8
# 4    Arkansas                  1.00            18.9         19.0
# 5  California                  0.31            22.5         22.7
#
#    act_17_reading  act_17_science  act_17_composite
# 1            19.7            19.4              19.2
# 2            20.4            19.9              19.8
# 3            20.1            19.8              19.7
# 4            19.7            19.5              19.4
# 5            23.1            22.2              22.8

# %% [markdown]
# #### 10. Merge Dataframes
#
# Join the 2017 ACT and SAT dataframes using the state in each dataframe as the key. Assign this to a new variable.

# %%
# Sorting both DataFrames by state before we merge

sat_17.sort_values(by="state", inplace=True)
act_17.sort_values(by="state", inplace=True)

# %%
#Merging:
act_sat_17 = pd.merge(act_17, sat_17, how="outer")

act_sat_17.info() # Confirming if there is any missing entry or null value.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   state                                      51 non-null     object
#  1   act_17_participation                       51 non-null     float64
#  2   act_17_english                             51 non-null     float64
#  3   act_17_math                                51 non-null     float64
#  4   act_17_reading                             51 non-null     float64
#  5   act_17_science                             51 non-null     float64
#  6   act_17_composite                           51 non-null     float64
#  7   sat_17_participation                       51 non-null     float64
#  8   sat_17_evidence_based_reading_and_writing  51 non-null     int64
#  9   sat_17_math                                51 non-null     int64
# ...

# %% [markdown]
# #### 11. Save your cleaned, merged dataframe
#
# Use a relative path to save out your data as `combined_2017.csv`.

# %%
#Exporting it to a new file
act_sat_17.to_csv("combined_2017.csv", index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning

# %% [markdown]
# Read in the `sat_2018.csv` and `act_2018.csv` files and assign them to appropriately named pandas dataframes. For the **2018 ACT Data**, only the `Composite` scores are available. Repeat the same processes to clean the 2018 data here as you were instructed in the previous sections above.

# %%
# Reading the files.
sat_18 = pd.read_csv("sat_2018.csv")
act_18 = pd.read_csv("act_2018.csv")

# %%
# Overviewing the DataFrame with info() method.
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
# Checking the number of unique values in State column to compare with the number of entry
sat_18["State"].nunique(dropna=False)
# Out:
# 51

# %%
# Overviewing the DataFrame with info() method.

act_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
# Checking the number of unique values in State column to compare with the number of entry
act_18["State"].nunique(dropna=False)
# Out:
# 51

# %% [markdown]
# In act_18 DataFrame there are 52 entries according to info() method; but, only 51 of them are unique in "state" column. We see that with .nunique() method. 1 entry seems to be duplicated; because there must be 51 entries.
# In order to find it; we will group by state, and count the values.
# When we sort them, we will be able see which state has more than 1 value.

# %%
# Since we know there is a duplicate in State column in act_18
# Below code groups by State, counts the number of states, and shows the top one (Ideally each must be 1)

act_18.groupby("State")["State"].count().sort_values(ascending=False).head()
# Out:
# State
# Maine            2
# Wyoming          1
# Idaho            1
# Michigan         1
# Massachusetts    1
# Name: State, dtype: int64

# %%
# Since we know Maine is duplicated, we are checking the index of both Maine entries.
act_18[act_18["State"] == "Maine"]
# Out:
#     State Participation  Composite
# 19  Maine            7%       24.0
# 20  Maine            7%       24.0

# %%
# Dropping one of them.
act_18.drop(axis="index",index=20, inplace=True)

# %%
# Reseting the index.
act_18.reset_index(drop=True, inplace=True)

# %%
# Checking the first 25 row to see whether it worked.
act_18.head(25)
# Out:
#                    State Participation  Composite
# 0                Alabama          100%       19.1
# 1                 Alaska           33%       20.8
# 2                Arizona           66%       19.2
# 3               Arkansas          100%       19.4
# 4             California           27%       22.7
# 5               Colorado           30%       23.9
# 6            Connecticut           26%       25.6
# 7               Delaware           17%       23.8
# 8   District of columbia           32%       23.6
# 9                Florida           66%       19.9
# 10               Georgia           53%       21.4
# 11                Hawaii           89%       18.9
# 12                 Idaho           36%       22.3
# 13              Illinois           43%       23.9
# 14               Indiana           32%       22.5
# 15                  Iowa           68%       21.8
# 16                Kansas           71%       21.6
# 17              Kentucky          100%       20.2
# ...

# %%
# Applying the convert_to_float function in "Participation" column in act_18 DataFrame

act_18["Participation"] = act_18["Participation"].apply(convert_to_float)

# %%
# Applying the convert_to_float function in "Participation" column in act_18 DataFrame

sat_18["Participation"] = sat_18["Participation"].apply(convert_to_float)

# %%
# Renaming the columns with lowercase.
sat_18.rename(columns={"State":"state", 
                       "Participation":"sat_18_participation",
                       "Evidence-Based Reading and Writing":"sat_18_evidence_based_reading_and_writing", 
                       "Math": "sat_18_math",
                       "Total":"sat_18_total",
                      }, inplace=True)

# %%
# Renaming the columns with lowercase.

act_18.rename(columns={"State":"state", 
                       "Participation":"act_18_participation",
                       "Composite" : "act_18_composite"
                      }, inplace=True)

# %%
# Confirming

print("=== sat_18 Dataframe ==")
print(sat_18.dtypes)
print("\n")
print("=== act_18 Dataframe ==")
act_18.dtypes
# Out:
# === sat_18 Dataframe ==
# state                                         object
# sat_18_participation                         float64
# sat_18_evidence_based_reading_and_writing      int64
# sat_18_math                                    int64
# sat_18_total                                   int64
# dtype: object
#
#
# === act_18 Dataframe ==
# state                    object
# act_18_participation    float64
# act_18_composite        float64
# dtype: object

# %% [markdown]
# #### Combine your 2017 and 2018 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names. Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged dataframe as `final.csv`.
#
# **Use this combined dataframe for the remainder of the project**.

# %%
# With the head() method we saw that "District of Columbia" is written with lower case in act_18
# below code shows it.
act_18[act_18["state"] == "District of columbia"]
# Out:
#                   state  act_18_participation  act_18_composite
# 8  District of columbia                  0.32              23.6

# %%
# Correcting the typo
act_18.iloc[8,0] = "District of Columbia"

# %%
# Confirming it.
act_18.iloc[8,0]
# Out:
# 'District of Columbia'

# %%
# Sorting the both DataFrames before we merge
sat_18.sort_values(by="state", inplace=True)
act_18.sort_values(by="state", inplace=True)

# %%
#Merging act_18 with sat_18 as act_sat_18:
act_sat_18 = pd.merge(act_18, sat_18, how="outer", on="state")

# %%
# checking first 5 entries
act_sat_18.head()
# Out:
#         state  act_18_participation  act_18_composite  sat_18_participation  \
# 0     Alabama                  1.00              19.1                  0.06
# 1      Alaska                  0.33              20.8                  0.43
# 2     Arizona                  0.66              19.2                  0.29
# 3    Arkansas                  1.00              19.4                  0.05
# 4  California                  0.27              22.7                  0.60
#
#    sat_18_evidence_based_reading_and_writing  sat_18_math  sat_18_total
# 0                                        595          571          1166
# 1                                        562          544          1106
# 2                                        577          572          1149
# 3                                        592          576          1169
# 4                                        540          536          1076

# %%
# Merging act_sat17 with act_sat_18 as final.
final = pd.merge(act_sat_17, act_sat_18, how="outer", on="state")

# %%
final.head()
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 0     Alabama                  1.00            18.9         18.4
# 1      Alaska                  0.65            18.7         19.8
# 2     Arizona                  0.62            18.6         19.8
# 3    Arkansas                  1.00            18.9         19.0
# 4  California                  0.31            22.5         22.7
#
#    act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 0            19.7            19.4              19.2                  0.05
# 1            20.4            19.9              19.8                  0.38
# 2            20.1            19.8              19.7                  0.30
# 3            19.7            19.5              19.4                  0.03
# 4            23.1            22.2              22.8                  0.53
#
#    sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %%
# exporting it to as final.csv
final.to_csv("final.csv", index=False)

# %%
# df = pd.read_csv("final.csv")
# df.head()
# df.tail()

# %% [markdown]
# ## Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#Showint the descriptive statistics of final DataFrame
final.describe().transpose()
# Out:
#                                            count         mean        std  \
# act_17_participation                        51.0     0.652549   0.321408
# act_17_english                              51.0    20.931373   2.353677
# act_17_math                                 51.0    21.182353   1.981989
# act_17_reading                              51.0    22.013725   2.067271
# act_17_science                              51.0    21.450980   1.739353
# act_17_composite                            51.0    21.519608   2.020695
# sat_17_participation                        51.0     0.398039   0.352766
# sat_17_evidence_based_reading_and_writing   51.0   569.117647  45.666901
# sat_17_math                                 51.0   556.882353  47.121395
# sat_17_total                                51.0  1126.098039  92.494812
# act_18_participation                        51.0     0.617255   0.340371
# act_18_composite                            51.0    21.496078   2.111583
# ...

# %% [markdown]
# #### Manually calculate standard deviation
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
# - Write a function to calculate standard deviation using the formula above

# %%
#After spent so much time on this formula, I came up to the line with mean.
# Since I could not complete it, I reserched and inspired from 
# https://stackoverflow.com/questions/24023927/computing-standard-deviation-without-packages-in-python
# I understood and adapted the code to my problem.


#import the numpy and math
import numpy as np
import math

# create a function called the_dv, that takes an argument as x.
def the_dv(x):
# num_list is a list that contains all the elements of the x. (assuming x has many elements inside)
    num_list = [int(i) for i in x]
# calculating mean of the num_list and assign it to variable called "mean"    
    mean = sum(num_list)/len(num_list)
# mean is subtracted from each element of the x and takes its 2nd power. Assigned it to a.
    a = abs((x-mean)**2)
# returns total of "a"s and divide by number of elements of x. Take its square root.
    return np.sqrt(sum(a)/len(x))
#     return np.sqrt(sum(a)/(len(x)-1))


## In the above code; it is showing 1/n as in the formula; but, it was actually calculated with 1/(n-1) in describe method.
## I used what I was asked to use

# %%
# using the_dv function 
final[["sat_17_math"]].apply(the_dv)
# Out:
# sat_17_math    46.657134
# dtype: float64

# %%
# using the_dv function 

final[["sat_17_math"]].std()
# Out:
# sat_17_math    47.121395
# dtype: float64

# %%
# using the_dv function 

final[["sat_18_math"]].apply(the_dv)
# Out:
# sat_18_math    47.301946
# dtype: float64

# %%
# using the_dv function 

final[["sat_18_total"]].apply(the_dv)
# Out:
# sat_18_total    93.227424
# dtype: float64

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
final.describe()
# Out:
#        act_17_participation  act_17_english  act_17_math  act_17_reading  \
# count             51.000000       51.000000    51.000000       51.000000
# mean               0.652549       20.931373    21.182353       22.013725
# std                0.321408        2.353677     1.981989        2.067271
# min                0.080000       16.300000    18.000000       18.100000
# 25%                0.310000       19.000000    19.400000       20.450000
# 50%                0.690000       20.700000    20.900000       21.800000
# 75%                1.000000       23.300000    23.100000       24.150000
# max                1.000000       25.500000    25.300000       26.000000
#
#        act_17_science  act_17_composite  sat_17_participation  \
# count       51.000000         51.000000             51.000000
# mean        21.450980         21.519608              0.398039
# std          1.739353          2.020695              0.352766
# ...

# %%
            #3         #4
sd = {column.name : the_dv(column) for column in #2
                                          [final[i] for i in final.columns #1
                                                if (final[i].dtype =='float64') or (final[i].dtype =='int64')]}


# NOTE: I tried this function so long; but I could not succeed.
# Researched how to apply a function in a dict comprehensions, and found this on the link below
# https://stackoverflow.com/questions/55048445/dictionary-comprehension-to-apply-a-function-to-dataframe-columns
# I understood and adapted it to my question.
#1 check every float or integer columns in final, 
#2 for each column apply the_dv function
#3 assign it as value of our new dictionary which is called sd
#4 assign that column's name to key



sd #calling the dictionary
# Out:
# {'act_17_participation': 0.4507510073069559,
#  'act_17_english': 2.3683101008026823,
#  'act_17_math': 2.014939397754775,
#  'act_17_reading': 2.0906586325552383,
#  'act_17_science': 1.790620184714062,
#  'act_17_composite': 2.057649525217414,
#  'sat_17_participation': 0.4734481723029228,
#  'sat_17_evidence_based_reading_and_writing': 45.21697020437866,
#  'sat_17_math': 46.65713364485503,
#  'sat_17_total': 91.58351056778743,
#  'act_18_participation': 0.440672391763706,
#  'act_18_composite': 2.1360124109208365,
#  'sat_18_participation': 0.515443579661167,
#  'sat_18_evidence_based_reading_and_writing': 47.03460978357609,
#  'sat_18_math': 47.30194550378352,
#  'sat_18_total': 93.22742384464433}

# %% [markdown]
# Do your manually calculated standard deviations match up with the output from pandas `describe`? What about numpy's `std` method?

# %% [markdown]
# Answer: No, it is because the formula we are askes to use is not same with .describe and numpy's std methods standard deviation formula. .describe method and numpy's std() use Bessel's correction which 1/(n-1).
# The main difference is coming from here. When I update my formula based on Bessel's correction, in some column's, I still have minor differences.

# %% [markdown]
# #### Investigate trends in the data
# Using sorting and/or masking (along with the `.head` method to not print our entire dataframe), consider the following questions:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? **Make a note of these and state *why* you think they're interesting**.
#
# **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# checking highest participation rates in sat_17 DataFrame

final.sort_values(by="sat_17_participation", ascending=False).head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 8   District of Columbia                  0.32            24.4         23.5
# 22              Michigan                  0.29            24.1         23.7
# 6            Connecticut                  0.31            25.5         24.6
# 7               Delaware                  0.18            24.1         23.4
# 29         New Hampshire                  0.18            25.4         25.1
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 8             24.9            23.5              24.2                  1.00
# 22            24.5            23.8              24.1                  1.00
# 6             25.6            24.6              25.2                  1.00
# 7             24.8            23.6              24.1                  1.00
# 29            26.0            24.9              25.5                  0.96
#
# ...

# %% [markdown]
# District of Columbia, Michigan, Connecticut, and Delaware have 100% participation in SAT exam in 2017.

# %%
# checking lowest participation rates in sat_17 DataFrame

final.sort_values(by="sat_17_participation", ascending=True).head()
# Out:
#            state  act_17_participation  act_17_english  act_17_math  \
# 34  North Dakota                  0.98            19.0         20.4
# 24   Mississippi                  1.00            18.2         18.1
# 15          Iowa                  0.67            21.2         21.3
# 25      Missouri                  1.00            19.8         19.9
# 44          Utah                  1.00            19.5         19.9
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 34            20.5            20.6              20.3                  0.02
# 24            18.8            18.8              18.6                  0.02
# 15            22.6            22.1              21.9                  0.02
# 25            20.8            20.5              20.4                  0.03
# 44            20.8            20.6              20.3                  0.03
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# In 2017, North Dakota, Mississipi and Iowa have the minimum participation rates in SAT exam in comparison with the other states.

# %%
# checking highest participation rates in sat_18 DataFrame

final.sort_values(by="sat_18_participation", ascending=False).head(10)
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 5               Colorado                  1.00            20.1         20.3
# 6            Connecticut                  0.31            25.5         24.6
# 7               Delaware                  0.18            24.1         23.4
# 22              Michigan                  0.29            24.1         23.7
# 12                 Idaho                  0.38            21.9         21.8
# 19                 Maine                  0.08            24.2         24.0
# 13              Illinois                  0.93            21.0         21.2
# 39          Rhode Island                  0.21            24.0         23.3
# 29         New Hampshire                  0.18            25.4         25.1
# 8   District of Columbia                  0.32            24.4         23.5
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# ...

# %% [markdown]
# Colorado, Connecticut, Delaware, Michigan and Idaho has 100% participation rates in the SAT exams in 2018.

# %%
# checking lowest participation rates in sat_18 DataFrame

final.sort_values(by="sat_18_participation", ascending=True).head()
# Out:
#            state  act_17_participation  act_17_english  act_17_math  \
# 34  North Dakota                  0.98            19.0         20.4
# 50       Wyoming                  1.00            19.4         19.8
# 41  South Dakota                  0.80            20.7         21.5
# 27      Nebraska                  0.84            20.9         20.9
# 49     Wisconsin                  1.00            19.7         20.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 34            20.5            20.6              20.3                  0.02
# 50            20.8            20.6              20.2                  0.03
# 41            22.3            22.0              21.8                  0.03
# 27            21.9            21.5              21.4                  0.03
# 49            20.6            20.9              20.5                  0.03
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# North Dakota has the minimum participation rate in SAT exam in 2018. Its rate is 2%

# %%
# checking highest participation rates in act_17 DataFrame

final.sort_values(by="act_17_participation", ascending=False).head(17)
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 0          Alabama                   1.0            18.9         18.4
# 17        Kentucky                   1.0            19.6         19.4
# 49       Wisconsin                   1.0            19.7         20.4
# 44            Utah                   1.0            19.5         19.9
# 42       Tennessee                   1.0            19.5         19.2
# 40  South Carolina                   1.0            17.5         18.6
# 36        Oklahoma                   1.0            18.5         18.8
# 33  North Carolina                   1.0            17.8         19.3
# 28          Nevada                   1.0            16.3         18.0
# 26         Montana                   1.0            19.0         20.2
# 24     Mississippi                   1.0            18.2         18.1
# 23       Minnesota                   1.0            20.4         21.5
# ...

# %% [markdown]
# 17 states has 100% participation rates in 2017 ACT exam.

# %%
# checking lowest participation rates in act_17 DataFrame

final.sort_values(by="act_17_participation", ascending=True).head()
# Out:
#             state  act_17_participation  act_17_english  act_17_math  \
# 19          Maine                  0.08            24.2         24.0
# 29  New Hampshire                  0.18            25.4         25.1
# 7        Delaware                  0.18            24.1         23.4
# 39   Rhode Island                  0.21            24.0         23.3
# 38   Pennsylvania                  0.23            23.4         23.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 19            24.8            23.7              24.3                  0.95
# 29            26.0            24.9              25.5                  0.96
# 7             24.8            23.6              24.1                  1.00
# 39            24.7            23.4              24.0                  0.71
# 38            24.2            23.3              23.7                  0.65
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# Maine has the lowest participation rate, 8%, in ACT exam in 2017. New Hampshire, Delaware, Rhode Island are the other low participation rate states. They all are from North East.

# %%
# checking highest participation rates in act_18 DataFrame

final.sort_values(by="act_18_participation", ascending=False).head(17)
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 0          Alabama                  1.00            18.9         18.4
# 17        Kentucky                  1.00            19.6         19.4
# 49       Wisconsin                  1.00            19.7         20.4
# 44            Utah                  1.00            19.5         19.9
# 42       Tennessee                  1.00            19.5         19.2
# 40  South Carolina                  1.00            17.5         18.6
# 36        Oklahoma                  1.00            18.5         18.8
# 35            Ohio                  0.75            21.2         21.6
# 33  North Carolina                  1.00            17.8         19.3
# 28          Nevada                  1.00            16.3         18.0
# 27        Nebraska                  0.84            20.9         20.9
# 26         Montana                  1.00            19.0         20.2
# ...

# %% [markdown]
# 17 states has 100% participation rates in 2018 ACT exam. Ohio and Nebraska are in the list different than the previous year.

# %%
# checking lowest participation rates in act_18 DataFrame

final.sort_values(by="act_18_participation", ascending=True).head(10)
# Out:
#             state  act_17_participation  act_17_english  act_17_math  \
# 19          Maine                  0.08            24.2         24.0
# 39   Rhode Island                  0.21            24.0         23.3
# 29  New Hampshire                  0.18            25.4         25.1
# 7        Delaware                  0.18            24.1         23.4
# 38   Pennsylvania                  0.23            23.4         23.4
# 22       Michigan                  0.29            24.1         23.7
# 47     Washington                  0.29            20.9         21.9
# 45        Vermont                  0.29            23.3         23.1
# 46       Virginia                  0.29            23.5         23.3
# 21  Massachusetts                  0.29            25.4         25.3
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 19            24.8            23.7              24.3                  0.95
# ...

# %% [markdown]
# The lowest participation in 2018 ACT exam list is exactly same with the previous year. Maine has the lowest rate with 7%. New Hampshire, Delaware, Rhode Island are also in the list.

# %%
# checking highest ave. total scores in sat_17 DataFrame

final.sort_values(by="sat_17_total", ascending=False).head()
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 23  Minnesota                  1.00            20.4         21.5
# 49  Wisconsin                  1.00            19.7         20.4
# 15       Iowa                  0.67            21.2         21.3
# 25   Missouri                  1.00            19.8         19.9
# 16     Kansas                  0.73            21.1         21.3
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 23            21.8            21.6              21.5                  0.03
# 49            20.6            20.9              20.5                  0.03
# 15            22.6            22.1              21.9                  0.02
# 25            20.8            20.5              20.4                  0.03
# 16            22.3            21.7              21.7                  0.04
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# Minnesota has the highest average total score in SAT in 2017. Wisconsin is in the second place

# %%
# checking lowest ave. total scores in sat_17 DataFrame

final.sort_values(by="sat_17_total", ascending=True).head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 8   District of Columbia                  0.32            24.4         23.5
# 7               Delaware                  0.18            24.1         23.4
# 12                 Idaho                  0.38            21.9         21.8
# 22              Michigan                  0.29            24.1         23.7
# 19                 Maine                  0.08            24.2         24.0
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 8             24.9            23.5              24.2                  1.00
# 7             24.8            23.6              24.1                  1.00
# 12            23.0            22.1              22.3                  0.93
# 22            24.5            23.8              24.1                  1.00
# 19            24.8            23.7              24.3                  0.95
#
# ...

# %% [markdown]
# DC has the lowest total avg. score in SAT exam in 2017. Delaware is in the second place

# %%
# checking highest ave. total scores in sat_18 DataFrame

final.sort_values(by="sat_18_total", ascending=False).head()
# Out:
#            state  act_17_participation  act_17_english  act_17_math  \
# 23     Minnesota                  1.00            20.4         21.5
# 49     Wisconsin                  1.00            19.7         20.4
# 34  North Dakota                  0.98            19.0         20.4
# 15          Iowa                  0.67            21.2         21.3
# 16        Kansas                  0.73            21.1         21.3
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 23            21.8            21.6              21.5                  0.03
# 49            20.6            20.9              20.5                  0.03
# 34            20.5            20.6              20.3                  0.02
# 15            22.6            22.1              21.9                  0.02
# 16            22.3            21.7              21.7                  0.04
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# Minnesota has the highest average score in SAT exam in 2018. Wisconsin is still in the second place.

# %%
# checking lowest ave. total scores in sat_18 DataFrame

final.sort_values(by="sat_18_total", ascending=True).head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 8   District of Columbia                  0.32            24.4         23.5
# 7               Delaware                  0.18            24.1         23.4
# 48         West Virginia                  0.69            20.0         19.4
# 12                 Idaho                  0.38            21.9         21.8
# 44                  Utah                  1.00            19.5         19.9
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 8             24.9            23.5              24.2                  1.00
# 7             24.8            23.6              24.1                  1.00
# 48            21.2            20.5              20.4                  0.14
# 12            23.0            22.1              22.3                  0.93
# 44            20.8            20.6              20.3                  0.03
#
# ...

# %% [markdown]
# DC has the lowest total avg. score in SAT exam in 2018. Delaware is in the second place

# %%
# checking highest ave. composite scores in act_17 DataFrame

final.sort_values(by="act_17_composite", ascending=False).head()
# Out:
#                    state  act_17_participation  act_17_english  act_17_math  \
# 29         New Hampshire                  0.18            25.4         25.1
# 21         Massachusetts                  0.29            25.4         25.3
# 6            Connecticut                  0.31            25.5         24.6
# 19                 Maine                  0.08            24.2         24.0
# 8   District of Columbia                  0.32            24.4         23.5
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 29            26.0            24.9              25.5                  0.96
# 21            25.9            24.7              25.4                  0.76
# 6             25.6            24.6              25.2                  1.00
# 19            24.8            23.7              24.3                  0.95
# 8             24.9            23.5              24.2                  1.00
#
# ...

# %% [markdown]
# New Hampshire, Massachusetts, Connecticut, and Maine have the highest ave. composite scores in ACT in 2017.
# Interesting enough NH and Maine are also in the lowest participation rates.
# Another interesting fact, first 4 of the highest average scores are from North East.

# %%
# checking lowest ave. composite scores in act_17 DataFrame

final.sort_values(by="act_17_composite", ascending=True).head()
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 28          Nevada                   1.0            16.3         18.0
# 24     Mississippi                   1.0            18.2         18.1
# 40  South Carolina                   1.0            17.5         18.6
# 11          Hawaii                   0.9            17.8         19.2
# 33  North Carolina                   1.0            17.8         19.3
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 28            18.1            18.2              17.8                  0.26
# 24            18.8            18.8              18.6                  0.02
# 40            19.1            18.9              18.7                  0.50
# 11            19.2            19.3              19.0                  0.55
# 33            19.6            19.3              19.1                  0.49
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# Nevada, Mississipi and S.Carolina have the lowest average composite scores in ACT exam in 2017.

# %%
# checking highest ave. composite scores in act_18 DataFrame

final.sort_values(by="act_18_composite", ascending=False).head()
# Out:
#             state  act_17_participation  act_17_english  act_17_math  \
# 6     Connecticut                  0.31            25.5         24.6
# 21  Massachusetts                  0.29            25.4         25.3
# 29  New Hampshire                  0.18            25.4         25.1
# 32       New York                  0.31            23.8         24.0
# 22       Michigan                  0.29            24.1         23.7
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 6             25.6            24.6              25.2                  1.00
# 21            25.9            24.7              25.4                  0.76
# 29            26.0            24.9              25.5                  0.96
# 32            24.6            23.9              24.2                  0.67
# 22            24.5            23.8              24.1                  1.00
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# Connecticut, Massachusetts and New Hampshire have the highest ave. composite scores in ACT in 2017.

# %%
# checking lowest ave. composite scores in act_18 DataFrame

final.sort_values(by="act_18_composite", ascending=True).head()
# Out:
#              state  act_17_participation  act_17_english  act_17_math  \
# 28          Nevada                   1.0            16.3         18.0
# 40  South Carolina                   1.0            17.5         18.6
# 24     Mississippi                   1.0            18.2         18.1
# 11          Hawaii                   0.9            17.8         19.2
# 0          Alabama                   1.0            18.9         18.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 28            18.1            18.2              17.8                  0.26
# 40            19.1            18.9              18.7                  0.50
# 24            18.8            18.8              18.6                  0.02
# 11            19.2            19.3              19.0                  0.55
# 0             19.7            19.4              19.2                  0.05
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# ...

# %% [markdown]
# Nevada, Mississipi and S.Carolina have the lowest average composite scores in ACT exam in 2018.

# %%
# creating a DataFrame of states with full participation in act in 2017.

act_full_part = final[final["act_17_participation"] == 1][["state"]]

# %%
# adding a new column of states with full participation in act in 2018.

act_full_part["2018 part."]=final[final["act_18_participation"] == 1][["act_18_participation"]]

# %%
# Calling the states with 100% participation in 2017 ACT; but not 100% participation in 2018.

act_full_part[act_full_part["2018 part."].isnull()]
# Out:
#         state  2018 part.
# 5    Colorado         NaN
# 23  Minnesota         NaN

# %% [markdown]
# Colorado and Minnesota had 100% average participation in ACT in 2017; but not 100% participation in 2018.

# %%
# showing the change in Colorado's participation to ACT between 2017 and 2018.

final.iloc[5][["state", "act_17_participation", "act_18_participation"]]
# Out:
# state                   Colorado
# act_17_participation           1
# act_18_participation         0.3
# Name: 5, dtype: object

# %%
# showing the change in Minnesota's participation to ACT between 2017 and 2018.

final.iloc[23][["state", "act_17_participation", "act_18_participation"]]
# Out:
# state                   Minnesota
# act_17_participation            1
# act_18_participation         0.99
# Name: 23, dtype: object

# %%
# creating a DataFrame of states with full participation in sat in 2017.

sat_full_part = final[final["sat_17_participation"] == 1][["state"]]

# %%
# adding a new column of states with full participation in sat in 2018.

sat_full_part["2018 part."]=final[final["sat_18_participation"] == 1][["sat_18_participation"]]

# %%
# Calling the states with 100% participation in 2017 ACT; but not 100% participation in 2018.

sat_full_part[sat_full_part["2018 part."].isnull()]
# Out:
#                   state  2018 part.
# 8  District of Columbia         NaN

# %% [markdown]
# DC had 100% average participation in ACT in 2017; but not 100% participation in 2018.

# %%
# showing the change in DC's participation to SAT between 2017 and 2018.

final.iloc[8][["state", "sat_17_participation", "sat_18_participation"]]
# Out:
# state                   District of Columbia
# sat_17_participation                       1
# sat_18_participation                    0.92
# Name: 8, dtype: object

# %%
# Do any states show have >50% participation on both tests either year?

states_part_list = [] #create an empty list to contain the result
sat_18_part = list(final[final["sat_18_participation"] > 0.5]["state"]) # list of states that had min 50% part. in SAT in 2018.
act_18_part = list(final[final["act_18_participation"] > 0.5]["state"]) # list of states that had min 50% part. in ACT in 2018.

for s in sat_18_part:      # For each state in sat_18_part list
    for a in act_18_part:  # check each state in act_18_part list
        if a == s:         # if they match, append it to states_part_list
             states_part_list.append(a)

states_part_list
# Out:
# ['Florida', 'Georgia', 'Hawaii', 'North Carolina', 'South Carolina']

# %% [markdown]
# Florida, Georgia, Hawaii, North Carolina, and South Carolina have at least 50% av. participation in both tests in 2018.

# %%
states_part_list = [] #create an empty list to contain the result
sat_17_part = list(final[final["sat_17_participation"] > 0.5]["state"]) # list of states that had min 50% part. in SAT in 2018.
act_17_part = list(final[final["act_17_participation"] > 0.5]["state"]) # list of states that had min 50% part. in ACT in 2018.


for s in sat_17_part:           # For each state in sat_18_part list
    for a in act_17_part:      # check each state in act_18_part list
        if a == s:              # if they match, append it to states_part_list
             states_part_list.append(a)

states_part_list
# Out:
# ['Florida', 'Georgia', 'Hawaii']

# %% [markdown]
# Florida, Georgia, and Hawaii have at least 50% av. participation in both tests in 2018.

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
final.corr()
# Out:
#                                            act_17_participation  \
# act_17_participation                                   1.000000
# act_17_english                                        -0.843501
# act_17_math                                           -0.861114
# act_17_reading                                        -0.866620
# act_17_science                                        -0.836595
# act_17_composite                                      -0.858134
# sat_17_participation                                  -0.841234
# sat_17_evidence_based_reading_and_writing              0.716153
# sat_17_math                                            0.682572
# sat_17_total                                           0.701477
# act_18_participation                                   0.918875
# act_18_composite                                      -0.780381
# sat_18_participation                                  -0.756479
# sat_18_evidence_based_reading_and_writing              0.522593
# ...

# %%
# Establish size of figure.
plt.figure(figsize=(14,10))

# creating a mask
mask = np.triu(np.ones_like(final.corr(), dtype=np.bool))

# creating a heatmap
sns.heatmap(final.corr(), annot=True, cmap="Blues", vmax=1.0, vmin=-1, mask=mask, linecolor="white", linewidths=1 );

plt.title("2017 - 2018 SAT and ACT exams average scores correlation table");

# %% [markdown]
# #### Define a custom function to subplot histograms
#
# We have data for two tests for two years. We only have composite (and not subtest scores) for the 2018 ACT. We should write a function that will take the names of 2+ columns and subplot histograms. While you can use pandas plotting or Seaborn here, matplotlib gives you greater control over all aspects of your plots.
#
# [Helpful Link for Plotting Multiple Figures](https://matplotlib.org/users/pyplot_tutorial.html#working-with-multiple-figures-and-axes)
#
# Here's some starter code:

# %%
# def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
#     nrows = int(np.ceil(len(list_of_columns)/2))          # Makes sure you have enough rows
#     fig, ax = plt.subplots(nrows=nrows, ncols=2)          # You'll want to specify your figsize
#     ax = ax.ravel()                                    # Ravel turns a matrix into a vector, which is easier to iterate
#     for i, column in enumerate(list_of_columns):         # Gives us an index value to get into all our lists
#         ax[i].hist(dataframe[column])                     # feel free to add more settings
#                                                   # Set titles, labels, etc here for each subplot

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels):
    nrows = int(np.ceil(len(list_of_columns)/2))          # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(10,10))          # You'll want to specify your figsize
    ax = ax.ravel()                                    # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns):         # Gives us an index value to get into all our lists
        ax[i].hist(dataframe[column])                   
        ax[i].set_title(list_of_titles[i])          # Set titles, labels, etc here for each subplot
#         ax[i].set_xlabel(list_of_xlabels[i])

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
# Using the subplot_histogram function for SAT & ACT Participation rates  
subplot_histograms(final,
                   ["act_17_participation", "act_18_participation","sat_17_participation" , "sat_18_participation"], 
                   ["2017 ACT participation", "2018 ACT Participation", "2017 SAT Participation", "2018 SAT Participation"], 
                   ["2017 ACT participation", "2018 ACT Participation", "2017 SAT Participation", "2018 SAT Participation"])
plt.tight_layout();

# %%
# Using the subplot_histogram function for SAT & ACT math scores  
subplot_histograms(final,
                   ["act_17_math","sat_17_math" , "sat_18_math"], 
                   ["2017 ACT math average score",  "2017 SAT math average score", "2018 SAT math average score"], 
                   ["2017 ACT math average score", "2017 SAT math average score", "2018 SAT math average score"])
plt.tight_layout();

# %%
# Using the subplot_histogram function for SAT & ACT reading scores  
subplot_histograms(final,
                   ["act_17_reading","sat_17_evidence_based_reading_and_writing" , "sat_18_evidence_based_reading_and_writing"], 
                   ["2017 ACT reading average score",  "2017 SAT Evidence-Based Reading and Writing average score", "2018 SAT Evidence-Based Reading and Writing average score"], 
                   ["2017 ACT reading average score",  "2017 SAT Evidence-Based Reading and Writing average score", "2018 SAT Evidence-Based Reading and Writing average score"])
plt.tight_layout();

# %% [markdown]
# #### Plot and interpret scatter plots
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
#
# Plot the two variables against each other using matplotlib or Seaborn
#
# Your plots should show:
# - Two clearly labeled axes
# - A proper title
# - Using colors and symbols that are clear and unmistakable
#
# **Feel free to write a custom function, and subplot if you'd like.** Functions save both time and space.

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 10))

# Create scatterplot of ACT 2017 avg math versus SAT 2017 av. math.
plt.scatter(final["act_17_math"],
           final["sat_17_math"],
            alpha=1 #shows the density, play with it
           )


plt.title("2017 SAT vs ACT Average math scores - state distribution ", fontsize = 20)
plt.ylabel("SAT 2017 Average Math Score", fontsize = 15)
plt.xlabel("ACT 2017 Average Math Score", fontsize = 15);
# Customizing the grid
plt.grid(linestyle='-', linewidth='0.3', color='grey')

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 10))

# Create scatterplot of ACT 2017 avg reading versus SAT 2017 av. Evidence-Based Reading and Writing Score.
plt.scatter(final["act_17_reading"],
           final["sat_17_evidence_based_reading_and_writing"],
            alpha=1 #shows the density
           )


plt.title("2017 SAT vs ACT Average verbal/reading scores - state distribution ", fontsize = 20)
plt.ylabel("SAT 2017 Average Evidence-Based Reading and Writing Score", fontsize = 15)
plt.xlabel("ACT 2017 Average Reading Score", fontsize = 15);
# Customizing the grid
plt.grid(linestyle='-', linewidth='0.3', color='grey')

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 10))

# Create scatterplot of total and composite scores in 2017.
plt.scatter(final["act_17_composite"],
           final["sat_17_total"],
            alpha=1 
           )


plt.title("2017 SAT vs ACT Average total scores - state distribution ", fontsize = 20)
plt.ylabel("SAT 2017 Average Total Score", fontsize = 20)
plt.xlabel("ACT 2017 Average Composite Score", fontsize = 20);
# Customizing the grid
plt.grid(linestyle='-', linewidth='0.3', color='grey')

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 10))

# Create scatterplot of ACT 2017 - 2018 avg. composite scores.
plt.scatter(final["sat_17_total"],
           final["sat_18_total"],
            alpha=1
           )


plt.title("2017 SAT vs 2018 SAT Average Total Score - state distribution ", fontsize = 20)
plt.ylabel("SAT 2017 Average Total Score", fontsize = 20)
plt.xlabel("SAT 2018 Average Total Score", fontsize = 20);
# Customizing the grid
plt.grid(linestyle='-', linewidth='0.3', color='grey')

# %% [markdown]
# There is positive correlation between SAT 2017 and SAT 2018 average composite scores.

# %%
# Establish the size of the figure.
plt.figure(figsize=(16, 10))

# Create scatterplot of ACT 2017 - 2018 avg. composite scores.
plt.scatter(final["act_17_composite"],
           final["act_18_composite"],
            alpha=1 #shows the density
           )


plt.title("2017 ACT vs 2018 ACT Average Composite Score - state distribution ", fontsize = 20)
plt.ylabel("ACT 2017 Average Composite Score", fontsize = 20)
plt.xlabel("ACT 2018 Average Composite Score", fontsize = 20);
# Customizing the grid
plt.grid(linestyle='-', linewidth='0.3', color='grey')

# %% [markdown]
# There is positive correlation between ACT 2017 and ACT 2018 average composite scores.

# %% [markdown]
# #### Plot and interpret boxplots
#
# For each numeric variable in the dataframe create a boxplot using Seaborn. Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#
# Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#
# Each boxplot should:
# - Only include variables of a similar scale
# - Have clear labels for each variable
# - Have appropriate titles and labels

# %%
# creating subplots for act17 composite and other scores.

fig, ax = plt.subplots(figsize=(10,10), squeeze=True);
ax.boxplot((final["act_17_composite"], final["act_17_math"], final["act_17_english"],final["act_17_reading"],final["act_17_science"]),
           labels=("act_17_composite","act_17_math","act_17_english", "act_17_reading", "act_17_science" )
           
           );


ax.set_ylim(0,28);
plt.title("2017 ACT Average Composite, Math, English, Reading and Science scores", fontsize = 15);

# %% [markdown]
# In 2017 ACT exam, english component has the lowest average score. Composite, math, reading and science components mininmum scores are very similar. Reading component has the highest avg. score.

# %%
# creating subplots for sat17 and 2018 total and other scores.

fig, ax = plt.subplots(figsize=(10,10), squeeze=True);
ax.boxplot((final["sat_17_total"], final["sat_17_math"], final["sat_17_evidence_based_reading_and_writing"],final["sat_18_total"],final["sat_18_math"], final["sat_18_evidence_based_reading_and_writing"]),
           labels=("sat_17_total","sat_17_math","sat_17_evidence_based_reading_and_writing", "sat_18_total", "sat_18_math", "sat_18_evidence_based_reading_and_writing")
          
          );


# ax.set_ylim(13,28);
plt.title("2017 and 2018 SAT Average Total, Math, Evindence-Based Reading and Writing scores", fontsize = 12);


plt.xticks(rotation = 45);
ax.set_ylim(200,1400);

# %% [markdown]
# When we compare SAT 2018, and 2018 total average scores, we see that 2017 has lower avg. score. Both has similar maximum values.

# %% [markdown]
# #### Feel free to do additional plots below
# *(do research and choose your own chart types & variables)*
#
# Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# We would like to see the correlation between ACT and SAT exam average participation rates in 2017.
# Establish the size of the figure.
plt.figure(figsize=(16, 10))

# Create scatterplot of 2017 ACT - SAT avg. PARTICIPATION.
plt.scatter(final["act_17_participation"],
           final["sat_17_participation"],
            alpha=1        
           )

z = np.polyfit(final["act_17_participation"], final["sat_17_participation"], deg=1)
p = np.poly1d(z)
plt.plot(final["act_17_participation"],p(final["act_17_participation"]),"r--")
plt.title("2017 ACT vs SAT Average Participation - state distribution ", fontsize = 20)
plt.ylabel("ACT 2017 Average Participation", fontsize = 20)
plt.xlabel("SAT 2017 Average Participation", fontsize = 20);
# Customizing the grid
plt.grid(linestyle='-', linewidth='0.3', color='grey')

# %%
# We would like to see the correlation between ACT and SAT exam average participation rates in 2018.

# Establish the size of the figure.
plt.figure(figsize=(16, 10))

# Create scatterplot of 2018 ACT - SAT avg. PARTICIPATION.
plt.scatter(final["act_18_participation"],
           final["sat_18_participation"],
            alpha=1        
           )

z = np.polyfit(final["act_18_participation"], final["sat_18_participation"], deg=1)
p = np.poly1d(z)
plt.plot(final["act_18_participation"],p(final["act_18_participation"]),"r--")
plt.title("2018 ACT vs SAT Average Participation - state distribution ", fontsize = 20)
plt.ylabel("ACT 2018 Average Participation", fontsize = 20)
plt.xlabel("SAT 2018 Average Participation", fontsize = 20);
# Customizing the grid
plt.grid(linestyle='-', linewidth='0.3', color='grey')

# %% [markdown]
# In both charts, the points lie close to the line that has negative gradient. We can say there is negative correlation between each exam participation rates.

# %%
# We would like to see what table correlation like between ACT participation rate and composite score.

# creating a new variable without Massachusetts and New Hampshire
exl_MA_and_NH = final[(final["state"] != "Massachusetts") & (final["state"] != "New Hampshire") ]

# taking only 4 columns 
exl_MA_and_NH = exl_MA_and_NH[["act_18_participation", "act_18_composite","act_17_participation", "act_17_composite"]]

# Establish size of figure.
plt.figure(figsize=(10,8))

# creating a mask
mask = np.triu(np.ones_like(exl_MA_and_NH.corr(), dtype=np.bool))

# creating a heatmap
sns.heatmap(exl_MA_and_NH.corr(), annot=True, cmap="Blues", vmax=1.0, vmin=-1, mask=mask, linecolor="white", linewidths=1);

plt.title("2017-2018 ACT exams av. participation and composite scores correlation table exc. MA & NH");

plt.yticks(rotation = 45);

# %% [markdown]
# We see correlation between ACT participation rate and composite score without New Hampshire and Massachusetts.
# When we removed tese 2 states, the negative correlation between ACT 17 participation rate vs composite score DECREASED from -0.86 to -0.85. This means, these 2 states change the direction of negative correlation.
# When all other states' participation rate is increasing 1 unit, their composite score decreases 0.85 unit.
# With NH and MA; when participation rate is incresing 1 unit, the average composite score decreased 0.86 unit.

# %%
# We would like to see Florida
final[final["state"]=="Florida"]
# Out:
#      state  act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 9  Florida                  0.73            19.0         19.4            21.0
#
#    act_17_science  act_17_composite  sat_17_participation  \
# 9            19.4              19.8                  0.83
#
#    sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# 9                                        520          497          1017
#
#    act_18_participation  act_18_composite  sat_18_participation  \
# 9                  0.66              19.9                  0.56
#
#    sat_18_evidence_based_reading_and_writing  sat_18_math  sat_18_total
# 9                                        550          549          1099

# %%
# We would like to see Ohio
final[final["state"]=="Ohio"]
# Out:
#    state  act_17_participation  act_17_english  act_17_math  act_17_reading  \
# 35  Ohio                  0.75            21.2         21.6            22.5
#
#     act_17_science  act_17_composite  sat_17_participation  \
# 35            22.0              22.0                  0.12
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# 35                                        578          570          1149
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 35                   1.0              20.3                  0.18
#
#     sat_18_evidence_based_reading_and_writing  sat_18_math  sat_18_total
# 35                                        552          547          1099

# %%
# We would like to see Wisconsin
final[final["state"]=="Wisconsin"]
# Out:
#         state  act_17_participation  act_17_english  act_17_math  \
# 49  Wisconsin                   1.0            19.7         20.4
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 49            20.6            20.9              20.5                  0.03
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# 49                                        642          649          1291
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 49                   1.0              20.5                  0.03
#
#     sat_18_evidence_based_reading_and_writing  sat_18_math  sat_18_total
# 49                                        641          653          1294

# %%
#We would like to see New York
final[final["state"]=="New York"]
# Out:
#        state  act_17_participation  act_17_english  act_17_math  \
# 32  New York                  0.31            23.8         24.0
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 32            24.6            23.9              24.2                  0.67
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# 32                                        528          523          1052
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 32                  0.27              24.5                  0.79
#
#     sat_18_evidence_based_reading_and_writing  sat_18_math  sat_18_total
# 32                                        534          534          1068

# %%
# We would like to see New Jersey
final[final["state"]=="New Jersey"]
# Out:
#          state  act_17_participation  act_17_english  act_17_math  \
# 30  New Jersey                  0.34            23.8         23.8
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 30            24.1            23.2              23.9                   0.7
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# 30                                        530          526          1056
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 30                  0.31              23.7                  0.82
#
#     sat_18_evidence_based_reading_and_writing  sat_18_math  sat_18_total
# 30                                        547          547          1094

# %%
# We would like to see Michigan
final[final["state"]=="Michigan"]
# Out:
#        state  act_17_participation  act_17_english  act_17_math  \
# 22  Michigan                  0.29            24.1         23.7
#
#     act_17_reading  act_17_science  act_17_composite  sat_17_participation  \
# 22            24.5            23.8              24.1                   1.0
#
#     sat_17_evidence_based_reading_and_writing  sat_17_math  sat_17_total  \
# 22                                        509          495          1005
#
#     act_18_participation  act_18_composite  sat_18_participation  \
# 22                  0.22              24.2                   1.0
#
#     sat_18_evidence_based_reading_and_writing  sat_18_math  sat_18_total
# 22                                        511          499          1011

# %%
final[(final["sat_17_participation"] <= .15) & (final["sat_18_participation"] <= .15)][["sat_17_participation", "sat_18_participation"]].agg(["count", "mean"])

# calling states with lower than 15% participation in both SAT exam
# Their mean and count
# Out:
#        sat_17_participation  sat_18_participation
# count             18.000000             18.000000
# mean               0.038333              0.043889

# %%
final[(final["sat_17_participation"] <= .25) & (final["sat_18_participation"] <= .25)][["sat_17_participation", "sat_18_participation"]].agg(["count", "mean"])

# calling states with lower than 25% participation in both SAT exam
# Their mean and count
# Out:
#        sat_17_participation  sat_18_participation
# count                20.000               20.0000
# mean                  0.046                0.0565

# %%
final[(final["act_17_participation"] <= .15) & (final["act_18_participation"] <= .15)][["act_17_participation", "act_18_participation"]].agg(["count", "mean"])

# calling states with lower than 15% participation in both ACT exam
# Their mean and count
# Out:
#        act_17_participation  act_18_participation
# count                  1.00                  1.00
# mean                   0.08                  0.07

# %%
final[(final["act_17_participation"] <= .25) & (final["act_18_participation"] <= .25)][["act_17_participation", "act_18_participation"]].agg(["count", "mean"])

# calling states with lower than 25% participation in both ACT exam
# Their mean and count
# Out:
#        act_17_participation  act_18_participation
# count                 5.000                  5.00
# mean                  0.176                  0.15

# %% [markdown]
# #### (Optional): Using Tableau, create a choropleth map for each variable using a map of the US.
#
# Save this plot as an image file in an images directory, provide a relative path, and insert the image into notebook in markdown.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based upon your observations, choose **three** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. (Make sure that you cite your sources -- check with you local instructor for citation preferences).

# %% [markdown]
# In general both exams participation rates are low in comparison with some other countries; such as Sweden, UK, S. Korea or Australia. When we look at the details, I am interested in researching about Florida, Ohio, and Winconsin. Wisconsin has the minimum participation rate in 2018 in SAT; but, second maximum in average total scores in the same exam. Similarly, Florida is the 6th lowest score in the SAT.

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Choose one state with a lower participation rate and provide a suggestion for how the College Board might increase participation amongst graduating seniors in this state. Are there additional data you desire that would better inform your investigations?

# %% [markdown]
# In general, the SAT exam average participation rates in 2017 and 2018 are low in comparison with the ACT exam, as well as other countries' equivalent exam participation rates.
# According to the European Parliament report (1); higher education entrance exam participation rates are following for some countries; Sweden 76%, South Korea 71%, UK 63% and Australia 96%. This shows that the SAT exam particiaption rate 45% in 2018 very low. Also, the ACT exam participation rate is 61% in 2018; that means 16% higher than the SAT participation rate.
#
# Our recommendation for the College Board to develop strategies for increasing participation in Florida, Ohio and Wisconsin states.
# We recommend Florida to focus on; because, it has the 6th lowest score in SAT; but its participation rate is in the 10 highest with 83%. Florida is the most populated country in the first 10 countries.(2) The students do not prefer to participate to the SAT exam. The College Board local office in Florida can research the reasons why they do not want to participate. Any increase in participation would help to US general participation rate.
#
# The second state we recommend the College Board to focus on is Ohio. Ohio's SAT average participation rates are 12% and 18% in 2017 and 2018. It has the eight lowest average participation rate in the SAT exams; but, Ohio is the 6th most populated country in the US. We see that there is big room for growing in Ohio. The students in Ohio do not prefer to attend SAT exam. In Ohio, participation could be increased to the level of Michigan due to social similarities in these 2 states. (3) Michigan participation rate is 100% in the SAT exam. Also, Ohio Department of Education pays students for taking the SAT and the ACT exams.(4) The College Board local office may collaborate with the Department of Education in Ohio to promote the SAT exam among the high school students.
#
# Our last recommendation is to focus on Wisconsin; because, it has minimum average participation rate in the SAT exam in 2018 while having second highest average score in country. Students prefer to attend in the ACT exam rather than the SAT exam in Ohio, even though they are successful in SAT exam. Similar to Florida, general success in the SAT exam can be a useful tool to promote it among the target group.
#
# Generally, while both the SAT and the ACT exam participation rates are lower than the similar tests participation rates around the world; the College Board is suggested to focus on promoting SAT exam in the US, particularly suggested states.
#
#
# (1) http://www.lse.ac.uk/business-and-consultancy/consulting/assets/documents/higher-education-entrance-qualifications-and-exams-in-europe.pdf
#
# (2) https://www.census.gov/popclock/
#
# (3) https://www.indexmundi.com/facts/united-states/quick-facts/compare/ohio.michigan -This website refers to US Census Bureau as source
#
# (4) http://education.ohio.gov/Topics/Testing/ACT-SAT-FAQs#FAQ2842

# %% [markdown]
# ## Bonus: Descriptive and Inferential Statistics

# %% [markdown]
# #### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
# Creating a histogram for SAT_17_participation with the line on it
sns.distplot(final[['sat_17_participation']], bins=10, kde = True, color="Blue"
);

# mean line adding
plt.vlines(x = np.mean(final["sat_17_participation"]), ymin=0, ymax=3.5, color='r');

# Add a title and show the plot.
plt.title('SAT 17 average participation rates');

# %% [markdown]
# The distribution of SAT 17 participation rates is not a normal distribution.

# %%
# Creating a histogram for SAT_18_participation with the line on it
sns.distplot(final['sat_18_participation'], bins=10, kde = True, color="Blue"
);


# mean line adding
plt.vlines(x = np.mean(final["sat_18_participation"]), ymin=0, ymax=3.5, color='r');


# Add a title and show the plot.
plt.title('SAT 18 average participation rates');

# %% [markdown]
# The distribution of SAT 18 participation rates is not a normal distribution.

# %%
# creating a histogram for ACT 2018 composite score
plt.hist(final["act_18_composite"], bins=20)
# labeling the x axes
plt.xlabel("Composite scores")

# mean line adding
plt.vlines(x = np.mean(final["act_18_composite"]), ymin=0, ymax=20, color='r');

# putting the title
plt.title('2018 ACT exam composite score distribution');

# %%
# creating a histogram for SAT 2018 composite score
plt.hist(final["sat_18_total"], bins=10)

# labeling the x axes
plt.xlabel("total scores")

# mean line adding
plt.vlines(x = np.mean(final["sat_18_total"]), ymin=0, ymax=20, color='r');

# putting the title
plt.title('2018 SAT exam total score distribution');

# %% [markdown]
# Both the ACT and SAT total score distributions are not normal distribution.

# %% [markdown]
# #### We generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?

# %% [markdown]
# Answer: We did not observe this given the histograms above.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
# creating a histogram for SAT 2018 MATH score
plt.hist(final["sat_18_math"], bins=10)

# labeling the x axes
plt.xlabel("math scores")

# mean line adding
plt.vlines(x = np.mean(final["sat_18_math"]), ymin=0, ymax=20, color='r');

# putting the title
plt.title('2018 SAT exam average math score distribution');

# %%
# creating a histogram for SAT 2017 MATH score
plt.hist(final["sat_17_math"], bins=10)

# labeling the x axes
plt.xlabel("math scores")


# mean line adding
plt.vlines(x = np.mean(final["sat_17_math"]), ymin=0, ymax=20, color='r');

# putting the title
plt.title('2017 SAT exam average math score distribution');

# %%
# creating a histogram for ACT 2017 MATH score
plt.hist(final["act_17_math"], bins=10)

# labeling the x axes
plt.xlabel("math scores")


# mean line adding
plt.vlines(x = np.mean(final["act_17_math"]), ymin=0, ymax=20, color='r');


# putting the title
plt.title('2017 ACT exam average math score distribution');

# %%
# creating a histogram for sat_18_evidence_based_reading_and_writing score
plt.hist(final["sat_18_evidence_based_reading_and_writing"], bins=10)

# labeling the x axes
plt.xlabel("evidence based reading writing scores")


# mean line adding
plt.vlines(x = np.mean(final["sat_18_evidence_based_reading_and_writing"]), ymin=0, ymax=20, color='r');


# putting the title
plt.title('2018 SAT exam average ev.b.reading writing score distribution', size=10);

# %%
# creating a histogram for sat_17_evidence_based_reading_and_writing score
plt.hist(final["sat_17_evidence_based_reading_and_writing"], bins=10)

# labeling the x axes
plt.xlabel("evidence based reading writing scores")

# mean line adding
plt.vlines(x = np.mean(final["sat_17_evidence_based_reading_and_writing"]), ymin=0, ymax=20, color='r');

# putting the title
plt.title('2017 SAT exam average ev.b.reading writing score distribution', size=10);

# %%
# creating a histogram for average act_17_reading score
plt.hist(final["act_17_reading"], bins=10)

# labeling the x axes
plt.xlabel("reading score scores")

# mean line adding
plt.vlines(x = np.mean(final["act_17_reading"]), ymin=0, ymax=20, color='r');

# putting the title
plt.title('2017 ACT exam average reading score distribution');

# %% [markdown]
# Answer: None of the above histograms are showing a normal distribution.

# %% [markdown]
# #### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Answer: I think it does not make sense; because either of the dataframe is a sample of the other. The SAT exam rates and scores do not represent the ACT exam. It is not its sample group.
# Same situtation applies to the ACT exam. We cannot look at the SAT exam and try to understand the ACT exam dataset.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores?
#
# Why or why not?

# %% [markdown]
# Answer:
# No it is not; because of following reasons.
# The main reason is that we do not know enouugh information/data to compare those 2. We do not know what they are meausring, what are the sections etc.
# The correlation between ACT 2017 and SAT 2017 math scores is -0.34. The correlation between ACT 2017 and SAT 2018 math scores is -0.42.Both correlation numbers suggest a weak correlation.

# %% [markdown]
# #### Statistical Evaluation of Distributions
#
# **If you feel it's appropriate**, using methods we discussed in class, run hypothesis tests to compare variables of interest in our dataset.

# %%
# Code:
